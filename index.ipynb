# %% [markdown]
# # BioCampus workshop: 3D Bioimage Analysis with Open Source Software
#
# ## Proposed by Montpellier Ressources Imagerie
#
# **Trainers:**
#
# - BAECKER Volker
# - BENEDETTI Clément
#
# **Requirements:** [Requirements & installation guide](exercises/extras/install-requirements.html)

# %% [markdown]
# ## Program
#
# ### 1. Image Acquisition and Encoding
# ### 2. Visualization
# ### 3. Reconstruction (Stitching, Alignment)
# ### 4. Image Deconvolution
# ### 5. Pre and Post-Processing (3D Filters and Morphomath)
# ### 6. Analysis
# #### 6.1 Spot Detection
# #### 6.2 Colocalization Analysis
# #### 6.3 Cell and Nuclei Segmentation
# #### 6.4 Volume, Area and Intensity Measurements
# #### 6.5 Tracking
# #### 6.6 Filament Tracing
# #### 6.7 Spatial distribution of cells/molecules
# ### 7. Output
# #### 7.1 Movies
# #### 7.2 Formats
